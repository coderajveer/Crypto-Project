# %%
 #This example uses Python 2.7 and the python-request library.
import json
import requests
def get_crypto_info(symbol):
    url = 'https://pro-api.coinmarketcap.com/v2/cryptocurrency/info'
    parameters = {
        'symbol': symbol
    }
    headers = {
        'Accepts': 'application/json',
        'X-CMC_PRO_API_KEY': 'a9369a4d-1231-4827-a774-93a18e73caec',  # Replace with your API key
    }

    session = requests.Session()
    session.headers.update(headers)

    try:
        response = session.get(url, params=parameters)
        response.raise_for_status()  # Raise an exception for HTTP errors
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return None

# Example usage:
symbol = 'BTC'
crypto_info = get_crypto_info(symbol)
if crypto_info:
    print(json.dumps(crypto_info, indent=4))
else:
    print("Failed to retrieve cryptocurrency info.")
# Out:
# {
#     "status": {
#         "timestamp": "2024-03-18T16:46:30.432Z",
#         "error_code": 0,
#         "error_message": null,
#         "elapsed": 10,
#         "credit_count": 1,
#         "notice": null
#     },
#     "data": {
#         "BTC": [
#             {
#                 "id": 1,
#                 "name": "Bitcoin",
#                 "symbol": "BTC",
#                 "category": "coin",
#                 "description": "Bitcoin (BTC) is a cryptocurrency launched in 2010. Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,657,781. The last known price of Bitcoin is 67,998.5716937 USD and is up 0.11 over the last 24 hours. It is currently trading on 10930 active market(s) with $44,972,981,703.30 traded over the last 24 hours. More information can be found at https://bitcoin.org/.",
#                 "slug": "bitcoin",
#                 "logo": "https://s2.coinmarketcap.com/static/img/coins/64x64/1.png",
# ...

# %%
crypto_info['data']['BTC'][10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 crypto_info['data']['BTC'][1]
#
# IndexError: list index out of range

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %%
list_1 = []
for i in glob.glob("Top 100 Crypto Coins/*"):
    print(i.split("\\"))
    list_1.append(i.split("\\")[1].split(".")[0])
# Out:
# ['Top 100 Crypto Coins', '1inch.csv']
# ['Top 100 Crypto Coins', 'Aave.csv']
# ['Top 100 Crypto Coins', 'Algorand.csv']
# ['Top 100 Crypto Coins', 'ApeCoin.csv']
# ['Top 100 Crypto Coins', 'Arweave.csv']
# ['Top 100 Crypto Coins', 'avalanche.csv']
# ['Top 100 Crypto Coins', 'Axie Infinity.csv']
# ['Top 100 Crypto Coins', 'Basic Attention Token.csv']
# ['Top 100 Crypto Coins', 'Binance USD.csv']
# ['Top 100 Crypto Coins', 'Bitcoin BEP2.csv']
# ['Top 100 Crypto Coins', 'bitcoin cash.csv']
# ['Top 100 Crypto Coins', 'Bitcoin Gold.csv']
# ['Top 100 Crypto Coins', 'Bitcoin SV.csv']
# ['Top 100 Crypto Coins', 'bitcoin.csv']
# ['Top 100 Crypto Coins', 'BitTorrent (New).csv']
# ['Top 100 Crypto Coins', 'BNB.csv']
# ['Top 100 Crypto Coins', 'cardano.csv']
# ['Top 100 Crypto Coins', 'Celo.csv']
# ['Top 100 Crypto Coins', 'Celsius.csv']
# ['Top 100 Crypto Coins', 'chainlink.csv']
# ['Top 100 Crypto Coins', 'Chiliz.csv']
# ['Top 100 Crypto Coins', 'Compound.csv']
# ...

# %%
dummy = pd.DataFrame(list_1, columns = ['crypto_history'])
 
dummy.to_csv("history_crypto.csv")

# %%
import requests

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start': '1',
  'limit': '5000',  # Adjust limit as per your requirement
  'convert': 'USD'  # Currency conversion
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'a9369a4d-1231-4827-a774-93a18e73caec',  # Replace with your API key
}

try:
    response = requests.get(url, params=parameters, headers=headers)
    data = response.json()
    symbols = [currency['symbol'] for currency in data['data']]
    print("Cryptocurrency Symbols:")
    print(symbols)
except Exception as e:
    print("Error:", e)
# Out:
# Cryptocurrency Symbols:
# ...

# %%
cypto_symbol = ['BTC', 'ETH', 'USDT', 'SOL', 'BNB', 'XRP', 'USDC', 'ADA', 'AVAX', 'DOGE', 'SHIB', 'DOT', 'TON', 'TRX', 'LINK', 'MATIC', 'NEAR', 'BCH', 'UNI', 'LTC', 'APT', 'LEO', 'ICP', 'DAI', 'FIL', 'ATOM', 'RNDR', 'ETC', 'TAO', 'IMX', 'GRT', 'STX', 'OKB', 'INJ', 'HBAR', 'XLM', 'CRO', 'OP', 'THETA', 'FDUSD', 'KAS', 'PEPE', 'MKR', 'VET', 'WIF', 'RUNE', 'MNT', 'XMR', 'FTM', 'TIA', 'LDO', 'AR', 'SEI', 'FET', 'ARB', 'ALGO', 'JUP', 'SUI', 'FLOW', 'FLOKI', 'AAVE', 'GALA', 'BEAM', 'EGLD', 'BONK', 'BSV', 'DYDX', 'PYTH', 'QNT', 'CFX', 'AXS', 'STRK', 'KCS', 'SAND', 'AGIX', 'WLD', 'ORDI', 'MINA', 'BTT', 'SNX', 'XTZ', 'AKT', 'APE', 'FLR', 'BGB', 'CHZ', 'MANA', 'TUSD', 'RON', 'HNT', 'AXL', 'EOS', 'NEO', 'KAVA', 'ETHDYDX', 'XEC', '1000SATS', 'WEMIX', 'IOTA', 'ZRX', 'CAKE', 'ROSE', 'AIOZ', 'KLAY', 'GNO', 'OSMO', 'JASMY', 'BLUR', 'DYM', 'WOO', 'LUNC', 'BTG', 'ASTR', 'ID', 'CRV', 'XRD', 'NEXO', 'RAY', 'CKB', 'MANTA', 'USDD', 'BOME', 'ENJ', 'GT', 'RBN', 'ENS', 'LUNA', 'IOTX', 'FTT', '1INCH', 'PRIME', 'XDC', 'ONDO', 'LPT', 'OCEAN', 'PENDLE', 'COMP', 'FXS', 'CELO', 'OM', 'SUPER', 'HOT', 'RPL', 'TWT', 'NFT', 'ZIL', 'LRC', 'PIXEL', 'GMT', 'ALT', 'XAUt', 'SC', 'CORE', 'TFUEL', 'FLUX', 'METIS', 'GLM', 'GAL', 'ILV', 'CSPR', 'MASK', 'SSV', 'GLMR', 'ANKR', 'TRAC', 'ZETA', 'GMX', 'QTUM', 'ZEC', 'AMP', 'BAT', 'SKL', 'MEME', 'ELF', 'MOBILE', 'XEM', 'DCR', 'GAS', 'KDA', 'WAVES', 'DASH', 'JTO', 'ONE', 'XCH', 'ETHW', 'ARKM', 'VANRY', 'PAXG', 'KSM', 'JOE', 'SUSHI', 'CVX', 'MX', 'ANT', 'BICO', 'RVN', 'DEXE', 'NTRN', 'BabyDoge', 'T', 'stETH', 'WTRX', 'WBTC', 'WHBAR', 'BTCB', 'WBETH', 'RETH', 'MSOL', 'ZBU', 'USDe', 'vBNB', 'WBNB', 'CHEEL', 'cbETH', 'FRAX', 'FTN', 'PAAL', 'ORBR', 'HEX', 'WKAVA', 'KUJI', 'ETHFI', 'STRD', 'TEL', '0x0', 'RLB', 'AUDIO', 'PORTAL', 'COQ', 'JST', 'XAI', 'MOG', 'SFP', 'POKT', 'DESO', 'AGI', 'AZERO', 'UMA', 'COTI', 'CFG', 'BAND', 'BORG', 'ICX', 'YFI', 'LSD', 'CHR', 'MAGIC', 'STORJ', 'ONT', 'RSR', 'ACH', 'vBTC', 'VTHO', 'BAL', 'API3', 'RLC', 'SFUND', 'CTC', 'EDU', 'WAXP', 'C98', 'POND', 'MYRO', 'NAKA', 'BDX', 'ATOR', 'FNSA', 'GF', 'ORCA', 'RSS3', 'AEVO', 'DAO', 'SXP', 'USTC', 'AI', 'YGG', 'STRAX', 'IQ', 'CTSI', 'LSK', 'IOST', 'CYBER', 'SLP', 'RIF', 'DGB', 'BONE', 'PROM', 'CELR', 'TRB', 'CQT', 'ADF', 'SYN', 'ACE', 'BIGTIME', 'TRUMP', 'NMR', 'FRONT', 'XVS', 'PHA', 'PYR', 'ALEX', 'ORAI', 'XNO', 'VVS', 'ZEN', 'OAS', 'ALPH', 'HIVE', 'BTRST', 'ZCX', 'AURORA', 'BNX', 'BORA', 'PEOPLE', 'SYS', 'TRIBE', 'PORK', 'POWR', 'NOIA', 'PYUSD', 'USDP', 'MBX', 'MAVIA', 'MOVR', 'GHX', 'USDB', 'ARK', 'SURE', 'POLYX', 'CGPT', 'NFP', 'FLEX', 'RBTC', 'NYM', 'LADYS', 'DENT', 'LCX', 'XPLA', 'PUNDIX', 'USDJ', 'TET', 'AITECH', 'SNT', 'MYRIA', 'XYM', 'APEX', 'TNC', 'WEN', 'ACA', 'HOOK', 'SDEX', 'SCRT', 'STG', 'SMOG', 'HBTC', 'MVL', 'ZBC', 'BOBA', 'HONEY', 'ABT', 'GNS', 'RDNT', 'XYO', 'LYX', 'SUN', 'KEEP', 'OMG', 'ELON', 'WIN', 'KNC', 'CUDOS', 'BFC', 'HFT', 'HT', 'vETH', 'ERG', 'DKA', 'DODO', 'STEEM', 'BLZ', 'GUSD', 'MRS', 'AUCTION', 'MLK', 'LQTY', 'ZIG', 'ATLAS', 'MAV', 'ERN', 'ALI', 'OXT', 'ONG', 'ALPHA', 'QI', 'WE', 'MTL', 'EURS', 'AGRS', 'DUSK', 'WILD', 'LUSD', 'PANDORA', 'MED', 'CVC', 'PHB', 'RACA', 'STPT', 'ALICE', 'ORBS', 'RAD', 'CHAT', 'SPELL', 'TLOS', 'GMT', 'POLIS', 'GTC', 'REQ', 'LOOM', 'ACS', 'LOOKS', 'TRIAS', 'PALM', 'SNEK', 'CTK', 'TOSHI', 'DAR', 'WMT', 'MBOX', 'POL', 'ankrETH', 'OGN', 'TON', 'CROWN', 'BFIC', 'RARE', 'HIFI', 'BAKE', 'ARDR', 'GAFI', 'vUSDC', 'VRA', 'REI', 'BITCOIN', 'BNT', 'ROOT', 'NKN', 'AGLD', 'WRX', 'TKO', 'GROK', 'PDA', 'BRISE', 'VR', 'UOS', 'CAH', 'HPO', 'CLV', 'MUBI', 'DNT', 'VAI', 'LAT', 'STMX', 'CTXC', 'MBL', 'NUM', 'ARPA', 'NXRA', 'BZR', 'TLM', 'QKC', 'AIDOGE', 'USDX', 'PRO', 'HIGH', 'POLY', 'PERP', 'POLS', 'XVG', 'GODS', 'CLORE', 'MAP', 'TOMI', 'BADGER', 'SWEAT', 'ORN', 'DIMO', 'WNXM', 'SDAO', 'PNG', 'CBK', 'REN', 'DMTR', 'MWC', 'FORT', 'ETN', 'XCAD', 'DAG', 'UQC', 'GOG', 'BUSD', '5IRE', 'NEON', 'FORTH', 'META', 'VIC', 'ATA', 'TRU', 'ALEPH', 'BANANA', 'DNX', 'FX', 'ULTIMA', 'LYRA', 'STIK', 'TRAC', 'SOV', 'LON', 'DPI', 'XCN', 'APX', 'CRE', 'SHRAP', 'ELA', 'COPI', 'XPRT', 'ALCX', 'DFC', 'KWD', 'DATA', 'XCHNG', 'MDT', 'FIDA', 'VRSC', 'LINA', 'SLND', 'DFI', 'TSUKA', 'KYVE', 'MKUSD', 'NPT', 'DEXT', 'CERE', 'AERGO', 'DERO', 'DEGO', 'BETA', 'MEME', 'REEF', 'LEVER', 'EWT', 'DIA', 'MPL', 'MOB', 'SAMO', 'RLY', 'GEL', 'COL', 'PLANET', 'KIN', 'ALT', 'DIONE', 'MTRG', 'COMBO', 'SNS', 'FUN', 'PAID', 'DORA', 'BTCP', 'OZO', 'FLM', 'METAL', 'TT', 'HUNT', 'vXVS', 'SBD', 'AEUR', 'HOPR', 'STRK', 'ZTX', 'GFAL', 'TOKEN', 'VRTX', 'ALT', 'IDEX', 'RARI', 'CPOOL', 'BSW', 'COREUM', 'AMPL', 'WXT', 'LEASH', 'CEEK', 'vBUSD', 'MLN', 'SOLO', 'MNW', 'VXV', 'CHEQ', 'EVER', 'FCT', 'QUACK', 'GLQ', 'KISHU', 'DEP', 'VEGA', 'ASM', 'GHST', 'IRIS', 'ROUTE', 'CEL', 'LIME', 'BEL', 'STOS', 'OPUL', 'EURC', 'PSTAKE', 'BMX', 'LOKA', 'RVF', 'VLX', 'UTK', 'LIT', 'GST', 'WHITE', 'GRS', 'CCD', 'EXRD', 'LTO', 'STT', 'MPLX', 'MCB', 'TAVA', 'KATA', 'ERC20', 'ABBC', 'CREAM', 'QUICK', 'HAI', 'SUSD', 'NEOM', 'WAN', 'LMWR', 'SIDUS', 'MOC', 'UPP', 'TURBO', 'RSV', 'MCT', 'CELL', 'HELLO', 'COS', 'CREO', 'MDX', 'MXC', 'AOG', 'BTCD', 'ASTRAFER', 'GFI', 'ZANO', 'SLIM', 'TARA', 'ALU', 'WNCG', 'AQT', 'ACX', 'WRLD', 'KWENTA', 'H2O', 'DCK', 'UNFI', 'VELO', 'NCT', 'PIT', 'KEY', 'AHT', 'ISIKC', 'MOON', 'HTM', 'COVAL', 'QUICK', 'BURGER', 'BLOK', 'CHESS', 'AVINOC', 'KLV', 'MIN', 'KMD', 'CAPS', 'VIDT', 'TRADE', '10SET', 'NIZA', 'GSWIFT', 'FLIX', 'WAGMIGAMES', 'PROPC', 'ABEL', 'ASD', 'UFO', 'MLT', 'SSX', 'FON', 'INSP', 'IDIA', 'VCNT', 'TABOO', 'AURA', 'XPR', 'NOM', 'AVA', 'IOT', 'SHX', 'CUSD', 'EURt', 'FIS', 'PSG', 'WIFI', 'KIMBO', 'NULS', 'DBC', 'WING', 'OFN', 'OORT', 'DERC', 'AMB', 'FOX', 'QRDO', 'VOXEL', 'XWC', 'PRQ', 'XSGD', 'CVTX', 'VOLT', 'DEL', 'STARL', 'AVT', 'NTX', 'BAR', 'OPTI', 'CAGA', 'KP3R', 'DOCK', 'vUSDT', 'HTR', 'ADX', 'SANTOS', 'NCDT', 'CSIX', 'RBX', 'BOSON', 'LOCUS', 'ALPACA', 'ARRR', 'HARD', 'PSP', 'ASTX', 'CENNZ', 'SOLAMA', 'CRTS', 'TONIC', 'UFT', 'SILLY', 'FARM', 'RAMP', 'STRX', 'PIVX', 'PONKE', 'FAR', 'PDT', 'BOND', 'BAD', 'QOM', 'PNK', 'BOTTO', 'GET', 'INV', 'GTAI', 'FIO', 'CONX', 'DVPN', 'VITE', 'IMGNAI', 'SLG', 'DVI', 'BZZ', 'SPA', 'SD', 'CETUS', 'ML', 'AXEL', 'CTX', 'ONIT', 'MCADE', 'BIFI', 'LING', 'JEWEL', 'CAST', 'WSG', 'PTS', 'MMIT', 'HERO', 'KAI', 'EPS', 'GFT', 'AKRO', 'MOBY', 'SOUL', 'RMRK', 'XNA', 'QORPO', 'MAN', 'FITFI', 'NODL', 'AST', 'KAR', 'SIS', 'SPS', 'UNIBOT', 'ORNJ', 'BBF', 'ALPINE', 'OG', 'WSM', 'TPT', 'XCP', 'YOOSHI', 'LAZIO', 'MONA', 'XEP', 'RKN', 'EL', 'QRL', 'LIKE', 'USDK', 'CET', 'POOLX', 'SHPING', 'NWC', 'CULT', 'FIRO', 'BCD', 'TIME', 'SCLP', 'VMINT', 'MATH', 'VGX', 'CITY', 'CATGIRL', 'DC', 'FYN', 'JESUS', 'TRVL', 'FOR', 'EPX', 'AIPAD', 'CWEB', 'FUL', 'FRM', 'DF', 'SWAP', 'DG', 'TROY', 'ARG', 'CRU', 'KEX', 'ICHI', 'POLA', 'SWFTC', 'RXD', 'DPR', 'PIP', 'YFII', 'PEPE2.0', 'SUKU', 'KILT', 'MIX', 'BNC', 'OTK', 'BOO', 'DFG', 'BDP', 'BCA', 'PORTO', 'AURY', 'GZONE', 'SWASH', 'HAPI', 'FUSE', '3ULL', 'BABYBONK', 'KRL', 'DRGN', 'JOY', 'RENBTC', 'DREP', 'SDN', 'BROCK', 'SRM', 'MNGO', 'REVV', 'DCB', 'EFX', 'SQUIDGROW', 'HEZ', 'SQR', 'GMM', 'NAVI', 'AKITA', 'SHIDO', 'ZUSD', 'SFD', 'SAITO', 'KSP', 'ISK', 'FSN', 'CUMMIES', 'ZF', 'PROPS', 'STC', 'UBT', 'BST', 'SOLVE', 'BBL', 'UX', 'HVH', 'AMO', 'TPY', 'AE', 'BEAM', 'ROA', 'LAMB', 'STEP', 'LM', 'UNS', 'VIB', 'PMPY', 'PIB', 'AREA', 'HEGIC', 'BTCU', 'PROS', 'KASTA', 'ADS', 'ARTY', 'USDV', 'CVP', 'TOKE', 'AZIT', 'CUBE', 'MEV', '$MONG', 'VINU', 'PNT', 'DIME', 'BIOT', 'BTM', 'GRND', 'DVF', 'GENE', 'PUSH', 'XTM', 'OOKI', 'KCT', 'SMT', 'FNCY', 'WIKEN', 'FRA', 'EGG', 'SSWP', 'OHO', 'NIM', 'DUEL', 'AFC', 'JUV', 'YLD', 'NYC', 'LSS', 'RWA', 'NetZ', 'GAL', 'BIM', 'AEG', 'SN', 'COT', 'NEXA', 'HNS', 'SOFI', 'TKP', 'stWEMIX', 'ACM', 'NFTX', 'XDB', 'BRICK', 'LUSH', 'NVIR', 'BAN', 'EPIK', 'SWTH', 'UNCX', 'SHI', 'HYDRA', 'SELO', 'DIO', 'LA', 'LITH', 'XDEFI', 'WOMBAT', 'IZI', 'DLC', 'FEI', 'BAX', 'BIDR', 'REP', 'RPG', 'QTCON', 'UPUNK', 'BLY', 'OAX', 'PKF', 'NRG', 'GYEN', 'BSCPAD', 'GARI', 'XRT', 'OBSR', 'APM', 'GMEE', 'WWY', 'VALOR', 'BRN', 'ADP', 'TORN', 'OOE', 'BITCI', 'PBX', 'ATM', 'DFL', 'BTS', 'NEST', 'VEED', 'BEPRO', 'VAL', 'GAINS', 'HOGE', 'SPURS', 'MDAO', 'AGLA', 'LBL', 'INDY', 'RAIN', 'KAN', 'DOME', 'IDRT', 'OMAX', 'SHR', 'INTER', 'WAIT', 'OVR', 'TEMCO', 'vLINK', 'ARKI', 'ARIA20', 'GG', 'OUSD', 'GSWAP', 'WOW', 'SMURFCAT', 'UMB', 'BRWL', 'HONK', 'PRE', 'PLU', 'SOCKS', 'ISP', 'DECHAT', 'TAROT', 'SENATE', 'MASQ', 'PPC', 'ANALOS', 'WNZ', 'ID', 'SYLO', 'MUSE', 'VTS', 'HMND', 'GQ', 'SCPT', 'NETVR', 'CON', 'BTCXT', 'TAMA', 'OXEN', 'MV', 'STC', 'OXB', 'THG', 'HUSD', 'GRG', 'VIX', 'PZP', 'RISE', 'BUY', 'CGO', 'XWG', 'MULTI', 'MTD', 'ALGB', 'MTV', 'CEUR', 'NOW', 'UPO', 'ONE', 'REV3L', 'UFI', 'SHFT', 'LNC', 'BCUBE', 'GOVI', 'LOVELY', 'POR', 'BWO', 'GRACY', 'PKT', 'MENGO', 'RING', 'MANC', 'PTU', 'DACXI', 'TOWER', 'UFC', 'PMG', 'MEMEAI', 'ZKB', 'ISLM', 'SHOPX', 'RADAR', 'CHRP', 'BLT', 'STFX', 'FCON', 'EFI', 'MAHA', 'CCC', 'DIVI', 'SIN', 'STAT', 'WHALE', 'AMU', 'BOA', 'GEEQ', 'LOOT', 'FER', 'COLX', 'CWAR', 'XNC', 'KLEVA', 'FUND', 'NEX', 'RAE', 'CTI', 'BTR', 'GBYTE', 'HSF', 'SUB', 'MEE', 'SCP', 'WALLET', 'EQUAD', 'PDEX', 'TRA', 'HDN', 'PAW', 'KDAG', 'RFOX', 'GO', 'BLOCX', 'WOM', 'BABY', 'KUNCI', 'GAME', 'DARK', 'CDT', 'GRV', 'LITT', 'MBS', 'DEFIT', 'QUINT', 'THE', 'ACE', 'DOSE', 'UNB', 'NMC', 'SENSO', 'GMCOIN', 'IDV', 'ASK', 'IMPT', 'ES', 'ZNN', 'BTC2', 'DAD', 'HTD', 'BREED', 'DIP', 'PALLA', 'KLIMA', 'PERC', 'XED', 'XELS', 'BCN', 'GC', 'GORILLA', 'vLTC', 'CPR', 'DHT', 'CPH', 'INFRA', 'RBW', 'HAM', 'HC', 'ATR', 'ORC', 'DEFI', 'OLE', 'MCRT', 'ROCO', 'UNIX', 'BRG', 'SHIRYO', 'DSLA', 'DUST', 'PIKA', 'EMRX', 'TREEB', 'vDAI', 'DMD', 'KIBSHI', 'BTCST', 'SPH', 'KMA', 'GXA', 'WNT', 'TSUGT', 'MIR', 'DOBO', 'SWCH', 'STBU', 'GRIN', 'STRM', 'BEND', 'ORB', 'CBG', 'NYE', 'HOSKY', 'VERSE', 'EVZ', 'CRPT', 'LAND', 'CLEO', 'BF', 'VEXT', 'RIO', 'ANC', 'AVL', 'DOGA', 'EGO', 'CAS', 'WITCH', 'RAI', 'ETHAX', 'MINT', 'RGT', 'VSYS', 'MARS4', 'OGV', 'ACA', 'UMT', 'LCC', 'PBR', 'CHO', 'SOS', 'MOOV', 'PCX', 'PART', 'DEFROGS', 'VEST', '0XDEV', 'REV', 'ROOBEE', 'PLI', 'WELT', 'ASR', 'MTLX', 'WSI', 'VAI', 'GNY', 'PLF', 'LBP', 'DFYN', 'EML', 'RITE', 'CA', 'OOKS', 'SHILL', 'HZN', 'NAP', 'BONDLY', 'POLC', 'VC', 'REVO', 'LGCY', 'JGN', 'RET', 'SHEB', 'IGNIS', 'MVC', 'HYPR', 'AMON', 'LTX', 'MITX', 'CONE', 'NRK', 'HEC', 'NFTB', 'GRP', 'CRWNY', 'EGG', 'MOZ', 'ORT', 'TRC', 'POLK', 'CHI', 'SCOTTY', 'PNP', 'MNTC', 'BOZO', 'TEER', 'MOVE', 'SPX', 'KINE', 'BOLT', 'SNC', 'XHV', 'EXFI', 'TENT', 'PROPS', 'METFI', 'EPIC', 'RAINI', 'AART', 'CGG', 'CBX', 'BTCBAM', 'RBLS', 'BAAS', '$REKT', 'DAFI', 'LYM', 'POLX', 'DYP', 'STRP', 'ABOND', 'VPP', 'ALVA', 'SFI', 'UNO', 'PICKLE', 'DICE', 'DX', 'YUSRA', 'NEER', 'EFC', 'ERTHA', 'FEVR', 'vDOT', 'MYST', 'SHROOM', 'WOZX', 'UBXS', 'MINU', 'MONI', 'INTR', 'BEAT', 'VSP', 'GMMT', 'URUS', 'NHT', 'PEAK', 'VRT', 'STC', 'XTAG', 'BTSE', 'FO', 'ELMO', 'PEEL', 'VTC', 'BSCS', 'ADM', 'TFT', 'WLKN', 'KYL', 'ZYN', 'GLEEC', 'FEAR', 'CIV', 'SKEY', 'YAXIS', 'vSXP', 'KROM', 'IDEA', 'SPIRIT', 'BLP', 'WECAN', 'ARV', 'FREE', 'ASTA', 'PRNT', 'KOM', 'DJED', 'DAPPX', 'MOVEZ', 'OXBT', 'EXNT', 'IDLE', 'DONUT', 'CWS', 'SAUBER', 'WOOF', 'BKN', 'NVT', 'VIDYA', 'JULD', 'KEKE', 'LBC', 'RAZOR', 'SCCP', 'LUCA', 'CCT', 'DPS', 'SAM', 'VISION', 'XFC', 'UNICE', 'WEFI', 'CRT', 'EXE', 'VAB', 'PAWTH', 'WOM', 'CRP', 'BXX', 'TUNE', 'MCHC', 'SIGNA', 'KICK', 'TOMS', 'ARIX', 'PZM', 'BFT', 'PORNROCKET', 'VEMP', 'IQT', 'XTP', 'TIFI', 'BNANA', 'STARS', 'XTN', 'HI', 'PUSSY', 'ZEE', 'SALT', 'TUP', 'ONE', 'GST', 'PLY', 'JAM', 'AME', 'THN', 'JETTON', 'AIMX', 'UPC', 'ZAI', 'JOY', 'HOD', 'SAFE', 'AIBB', 'GHOST', 'IHC', 'KALM', 'LQR', 'GST', 'NBT', 'SNFT', 'HOTCROSS', 'O3', 'AXIS', 'KONO', 'MTA', 'PXP', 'CMP', 'GOAL', 'IPAD', 'SPC', 'VEUR', 'IDNA', 'XCV', 'PRISM', 'ITGR', 'VLXPAD', 'BBS', 'EBEN', 'RPG', 'WOOP', 'CIRUS', 'DAMEX', 'DOGGY', 'ASTRO', 'PUMLX', 'GOZ', 'SOIL', 'GAME', 'PING', 'ZAP', 'LUFC', 'CHEEMS', 'KMON', 'INSUR', 'BIP', 'DERI', 'KINGSHIB', 'SUTER', 'PPT', 'XRUNE', 'SERO', 'SELF', 'PMON', 'VV', 'SHIA', 'ZELIX', 'RAIN', 'ODDZ', 'DPET', 'KING', 'MAX', 'MSTR', 'BLOX', 'ALLIN', 'IGU', 'VCF', 'K21', 'BIRD', 'CONV', 'CSM', 'MARSH', 'BIFI', 'NFTART', 'JAM', 'MOD', 'AIRI', 'TRAVA', 'CATMAN', 'EMAGIC', 'BCMC', 'SOULS', 'PEX', 'MRST', 'WICC', 'GOC', 'AOA', 'MONA', 'JMPT', 'YAM', 'UBX', 'DRF', 'PAY', 'SPO', 'OMC', 'ALY', 'CTT', 'FB', 'NORD', 'LAYER', 'OTO', 'NSFW', 'ORARE', 'EDG', 'LIGHT', 'DREAMS', 'NBLU', 'NABOX', 'PAC', 'OLT', 'KLO', 'TIN', 'HORD', 'XOR', 'EVA', 'HAWK', 'PLR', 'SKEB', 'WALV', 'TRIX', 'SPORE', 'TOP', 'AOG', 'AUTO', 'OGGY', 'WTC', 'TULIP', 'MNFT', 'OJA', 'MF', 'DDX', 'BASE', 'ETHPAD', 'FRIN', 'SMI', 'XFT', 'HIPENGUINS', 'MARO', 'ROOK', 'CARBON', 'GMPD', 'ZOO', 'SRK', 'JOB', 'VCHF', 'KAT', 'CATHEON', 'AM', 'ELDA', '0xBTC', 'KNIGHT', 'FLX', 'DINGO', 'MAPS', 'BIST', 'SHA', 'ODIN', 'ELMON', '1ART', 'XMON', 'POSI', 'eRSDL', 'BHO', 'AVATLY', 'BGL', 'HIBS', 'KUBE', 'ARDX', 'CTG', 'BRZE', 'HAKKA', 'STAKE', 'UNISTAKE', 'YBO', 'DONS', 'AKI', 'NSBT', 'CINU', 'BRKL', 'MTH', 'NAVI', 'BTCZ', 'PLASTIK', 'KZEN', 'PLT', 'vBCH', 'CEP', 'MMAI', 'PERI', 'ADAPAD', 'XNL', 'MEFA', 'XPM', 'GIO', 'APL', 'ATT', 'EM', 'STM', 'ALPHABET', 'EXM', 'XRPH', 'XY', 'GLCH', 'AX', 'CTCN', 'BLAST', 'SYNC', 'PACE', 'TIPS', 'BELT', 'PTP', 'LABS', 'LEG', 'ELAND', 'CLO', 'SHND', 'AVG', 'DXGM', 'GALO', 'SPARTA', 'EOSDT', 'BTX', 'SPFC', 'CZGOAT', 'MITH', 'MMA', 'HIDOODLES', 'ILC', 'IOEN', 'FEX', 'PUT', 'RFUEL', 'MFC', 'DEC', 'CAT', 'KTN', 'FWC', 'FTC', 'GRLC', 'EUM', 'NIX', 'HIENS3', 'FRKT', 'LOCG', 'IBFK', 'NINO', 'DON', 'PKR', 'VEX', 'MRX', 'GFI', 'BITS', 'REGENT', 'PETS', 'TRV', 'ABYSS', 'GLINT', 'YEC', 'LINKA', 'DTX', 'IBS', 'A', 'NAFT', 'DCN', 'KSN', 'HYVE', 'GOB', 'OLY', 'WEST', 'THC', 'PVU', 'SLRS', 'SLICE', 'C20', 'EDEN', 'MINT', 'X', 'RVLT', 'HMQ', 'PLSPAD', 'TOKO', 'BLANK', 'PYM', 'XPC', 'XBC', 'ARCONA', 'ATOLO', 'PFL', 'WZRD', 'IMT', 'PERL', 'FBX', 'ACQ', 'SKILL', 'COR', 'SAKAI', 'KOK', 'AIT', 'AGA', 'OXY', 'ACK', 'CYC', 'LOWB', 'FARA', 'DXL', 'ZOON', 'SALD', 'TONE', 'BXC', 'PXC', 'MIST', 'EARN', 'VEIL', 'CRA', 'OGGY', 'MINTME', 'STRONG', 'IOI', 'STARSHIP', 'VNXAU', 'ICE', 'FWT', 'UDO', 'ZEFU', 'POR', 'ISLAMI', 'ZCL', 'CO', 'REAP', 'CLEG', 'OCE', 'GOLD', 'GNX', 'BIS', 'SNM', 'COMBO', 'BHC', 'SOV', 'TH', 'OPIUM', 'SOHOT', 'FINA', 'WFAI', 'CLOAK', 'VIT', 'S4F', 'NFTY', 'SHOP', 'KRIPTO', 'BMON', 'GTH', 'EUNO', 'METAQ', 'CFi', '404A', 'PLOT', 'BALPHA', 'VXL', 'NEI', 'STND', 'KCCPAD', 'HANDY', 'TXA', 'NBS', 'NERD', 'ZER', 'DIGG', 'erowan', 'TKING', 'AWC', 'SUMO', 'PLAY', 'SATA', 'LTRBT', 'WSG', 'HYPER', 'HPB', 'AGATA', 'BOB', 'HUSL', 'MTVT', 'HUSH', 'QRT', 'FXDX', 'DDK', 'WNDR', 'SHI', 'XLD', 'XRP', 'BBANK', 'BMI', 'MAT', '8PAY', 'ETHO', 'SWP', 'EQZ', 'ZIK', 'PAPI', 'HAN', 'GEM', 'NFTD', 'ROCKI', 'XPNET', 'RFR', 'MASS', 'LEV', 'COT', 'SCC', 'TRR', 'PAINT', 'AZY', 'PAR', 'KABY', 'PACOCA', 'ALA', 'SATT', 'BLKC', 'XBY', 'ZLW', 'BIN', 'CNS', 'HIFLUF', 'HIFIDENZA', 'PEL', 'IF', 'BANK', 'CVT', 'TROLL', 'LIFE', 'DRT', 'AZ', 'CTT', 'QRK', 'KANGAL', 'UBEX', 'ZYB', 'LFW', 'INEX', 'RAZE', 'DESU', 'PLANETS', 'TIDAL', 'HIBAYC', 'KDG', 'HIPUNKS', 'OPEN', 'CLS', 'TITAN', 'GLC', 'DNXC', 'FTG', 'QWAN', 'BTB', 'KAMPAY', 'PTF', 'HGET', 'OCTO', 'SILVA', 'COOK', 'RPZX', 'ACN', 'HIMAYC', 'HTML', 'DFA', 'LNR', 'SWINGBY', 'RUFF', 'TXL', 'CNB', 'MPH', 'DDOS', 'DEXA', 'CRP', 'BUY', 'BeAI', 'RACEFI', 'MEMEMINT', 'WATCH', 'HICOOLCATS', 'AG8', 'SWRV', 'BLINK', 'DRC', 'UBDN', 'SOUL', 'CRX', 'CNTR', 'TFBX', 'HISQUIGGLE', 'MIBR', 'XCUR', 'OBX', 'FOR', 'MTC', 'AITRA', 'LANC', 'FINE', 'DWEB', 'NUX', 'VAL', 'HIAZUKI', 'ROYA', 'HGOLD', 'NGM', 'HELMET', 'SWOP', 'LKR', 'ASPO', 'HBX', 'STEP', 'BUSY', 'ALL', 'ROUSH', 'NEWS', 'SAO', 'HIMFERS', 'XIO', 'STV', 'MUDOL2', 'CAI', 'KTON', 'HIMEEBITS', 'XNO', 'RVC', 'SNB', 'DHV', 'SXS', 'DZG', 'SFX', 'PWAR', 'ATP', 'ESD', 'YF-DAI', 'GCOIN', 'DAWN', 'DUCKIES', 'XCASH', 'EXGO', 'TKS', 'EVRY', 'DDIM', 'DAVIS', 'SKU', 'RAINBOW', 'AC', 'FCL', 'MSU', 'LDOGE', 'OIN', 'TRAXX', 'MYRA', 'WAG', 'CYCLUB', 'SDT', 'CPO', 'APRIL', 'PLC', 'BAKE', 'PLAY', 'UCH', 'DYNA', 'PCNT', 'SNOW', 'ING', 'SHARE', 'APN', 'TANK', 'SAKE', 'NEBL', 'SHRED', 'WSPP', 'INXT', 'BTRS', 'MAKI', 'PASC', 'NRV', '1EARTH', 'HNTR', 'FPFT', 'NOR', 'BAC', 'ARES', 'BANANA', 'GLS', 'NAX', 'SMART', 'T99', 'L2', 'LEAD', 'AD', 'GMAT', 'MOTA', 'KART', 'MOMA', 'HICLONEX', 'TRL', 'SYP', 'SPWN', 'ZUM', 'UPI', 'KEYFI', 'HIUNDEAD', 'IDRX', 'HIGAZERS', 'AXIS', 'TIK', 'UPX', 'X42', 'DCNTR', 'TKB', 'PYME', 'DOP', 'HIRENGA', 'RUSH', 'SPORT', 'APY', 'IPX', 'POLI', 'EZ', 'APYS', 'PPAY', 'BDP', 'GDAO', 'NEU', 'ZNZ', 'GOF', 'JRT', 'HIBEANZ', 'ORION', 'TCP', 'SNOB', 'GSTS', 'HIFRIENDS', 'ARGON', 'DINO', 'FYD', 'BP', 'HOPE', 'HIMOONBIRDS', 'APL', 'DEM', 'MILK2', 'GARD', 'BPS', 'CLX', 'FS', 'HIENS4', 'FXF', 'GS', 'SEON', 'COGI', 'FIN', 'ETHA', 'NEXT', 'NYZO', 'ALN', 'BEER', 'HIODBS', 'GEO', 'NOV', 'TYC', 'PHX', 'RITO', 'MSB', 'DONA', 'PRCY', 'VDR', 'HISAND33', 'JET', 'AYA', 'RUNE', 'TELOS', 'HIVALHALLA', 'HIOD', 'AMA', 'BTZC', 'HISEALS', 'CORGIB', 'IGG', 'ORAO', 'FORM', 'CANDY', 'DOWS', 'XWP', 'ARGO', 'BUNNY', 'BC', 'CRE8', 'ZORA', 'XAS', 'EBA', 'CHICKS', 'WOW', 'PHR', 'FTX', 'BCUG', 'SHIELD', 'XLAB', 'BOLI', 'BRY', 'IQ', 'METAX', 'ASW', 'YVS', 'AIRT', 'DOGES', 'HYPE', 'BUNI', 'FLASH', 'GENESIS', 'TBX', 'FRTS', 'TCS', 'SNY', 'MEVR', 'JADE', 'FBN', 'VSO', 'DUCK', 'FREED', 'RBLX', 'TNT', 'SHACK', 'HERO', 'SABLE', 'ALLBI', 'BURN', 'YIELD', 'SHARD', 'N8V', 'DAPP', 'ZUM', 'TIP', 'WQT', 'EKTA', 'SENC', 'UCA', 'XCT', 'SPUME', 'MSWAP', 'YTN', 'NEVA', 'FOC', 'BYN', 'GMD', 'EVY', 'SOLX', 'LYRA', 'OPCT', 'GUM', '$ANRX', 'MCC', 'LFG', 'ATMOS', 'RGP', 'MMO', 'KWT', 'HIBAKC', 'SHOE', 'SFUEL', 'SCONEX', 'RED', 'TZC', 'LUA', 'CORX', 'AFEN', 'FLIXX', 'POLIS', 'DIFI', 'BEM', 'BETU', 'VIVO', 'INN', 'STAK', 'TOTM', 'KCASH', 'NSURE', 'XUI', 'PRARE', 'OMC', 'EGG', 'BTT', 'BLS', 'SKP', 'XDOGE', 'NRFB', 'RAGE', 'BOUTS', 'AZUKI', 'SMTY', '1UP', 'PYRO', 'ALPHR', 'ISA', 'RENA', 'TAP', 'NTRN', 'AIM', 'NCash', 'CTT', 'ARCH', 'KGO', 'ERA', 'KUV', 'UNI', 'HTZ', 'KFT', 'MEL', 'GOSS', 'BNU', 'LUC', 'UFARM', '1MIL', 'LUS', 'DOM', 'LITHO', 'SKYRIM', 'TWIN', 'GDR', 'NDX', 'GXT', 'SGT', 'SWP', 'ARCO', 'CSPN', 'FIU', 'ETNA', 'TEM', 'GAJ', 'ROOM', 'PXT', 'MOWA', 'INNBC', 'MDTK', 'NIFT', 'SNN', 'SWG', 'XDNA', 'PRVC', 'HXA', 'STREAM', 'SCHO', 'FLL', 'CNTM', 'ECO', 'MARTK', 'AVA', 'BNF', 'AXE', 'KWS', 'ACOIN', 'GRIMM', 'KWIK', 'REW', 'BSL', 'PHNX', 'CARE', 'PAYB', 'FUZE', 'ELET', 'FOTA', 'XMV', 'LAND', 'XGM', 'DONU', 'MATE', 'EGG', 'FBX', 'CRDT', 'KZC', 'KEMA', 'CYL', 'IRA', 'ZCR', 'SCAP', 'SEFA', 'CBIX-P', 'ECU', 'STO', 'SFG', 'PIAS', 'PRMX', 'ASKO', 'ARNX', 'WSPP', 'CPAN', 'RNBW', 'DRC', 'YFFII', 'SOL', 'WETH', 'SLERF', '$NAP', 'USDC.e', 'WAVAX', 'JITOSOL', 'BXC', 'USDE', 'BSOL', 'HTX', 'NADA', 'TRY', 'SATS', 'WMATIC', 'rats', 'EZETH', 'USDbC', 'WSTETH', 'vCAKE', 'BTC.b', 'PENG', 'POPCAT', 'JLP', 'TROLL', 'LAI', 'weETH', 'CNX', 'CRVUSD', 'ALITA', 'MMXN', 'vADA', 'UZX', 'NOTE', 'DMAIL', 'GPT', 'PUNKAI', 'WBT', 'WPLS', 'NMT', '1CAT', 'BODEN', 'POOH', 'WBS', 'SCA', 'AERO', 'PORT3', 'NOS', 'axlUSDC', 'WCANTO', 'ZKF', 'BABYSOL', 'BALLZ', 'SOLS', 'PEPE', 'WHALES', 'NIBI', 'ORDS', 'MICE', 'SAVM', 'ELU', 'TREMP', 'VNDC', 'NGL', 'CYBONK', 'XEN', 'NEVER', 'BRETT', 'slisBNB', 'MEDIA', 'TDROP', 'MUSIC', 'BOB', 'GEC', 'PLSX', 'TURT', 'ZUZALU', 'DOGE', 'ANDY', 'BENDOG', 'vXRP', 'HARAMBE', 'DUKO', 'DGI', 'FLY', 'vDOGE', 'MPT', 'JSM', 'ZERO', 'TOX', 'WFTM', 'SMILEY', 'PRISMA', '.COM', 'FIRE', 'TBTC', 'GPU', 'sAVAX', 'BABYGROK', 'UP', 'VELO', 'APEWIFHAT', 'STRUMP', 'SOLC', 'WHOREN', 'EDLC', 'CR', 'SERSH', 'GOO', 'WSTUSDT', 'vMATIC', 'PAJAMAS', 'BVM', 'WCRO', 'FLIP', 'NAVX', 'BETH', 'MNDE', 'WYNN', 'TRUMPEPE', 'vFIL', 'VRC', 'XTUSD', 'ZEND', 'ZYN', 'BONK2.0', 'OPSEC', 'BORK', 'SAROS', 'OLAS', 'BRT', 'MMSS', 'SLN', 'XPET', 'SCT', 'WEGLD', 'ENTC', 'SWETH', 'AXGT', 'WAMPL', 'SHDW', 'GME', 'BSSB', 'P2PS', 'WNEAR', 'USDT.e', 'LBR', 'USD+', 'BABY', 'LBK', 'PEPE', 'CORGIAI', 'XETA', 'NOCHILL', 'HGPT', 'WTAO', 'vUNI', 'OMNI', 'PPT', 'BOBO', 'RSETH', 'NEXT', 'YES', 'XAVA', 'PT', 'THL', 'stSOL', 'ICE', 'AWT', 'FLC', 'MAV', 'BTCS', 'IPV', 'VANA', 'DOG', 'PUFETH', 'AVIVE', 'SORA', 'WOLF', 'FLOKITA', 'FRXETH', 'HASUI', 'MILO', 'HXXH', 'TITANX', 'FAM', 'KOL', 'METH', 'GUI', 'USDP', 'Dovi', 'enqAI', 'LHINU', 'HEMULE', 'SAUCE', 'WMNT', 'SPACE', 'OHM', 'RPK', 'LVN', 'LIGO', 'QUBIC', 'AAST', 'APX', 'PDX', 'BCUT', 'FLZ', 'BFICGOLD', 'SEED', 'MMUI', 'AVAV', 'SOLAMB', 'EPEP', 'PETS', 'USDH', 'STF', 'CDX', 'QANX', 'STAR', 'GRAIL', 'CRH', 'PURSE', 'XT', 'SYNC', 'SCALE', 'PATEX', 'DOJO', 'BIT', 'HEX', 'DIFX', 'POU', 'WORK', 'TECH', 'GFY', 'REVO', 'BNSx', 'SI', 'PEPE', 'CATBOY', 'USEDCAR', 'BABYELON', 'BABY', 'HOLD', 'FMB', 'CZOL', 'TENET', 'OKT', 'WOJAK', 'STARS', 'WGLMR', 'UXD', 'TAONU', 'CHEX', 'TYPE', 'TBC', 'W', 'AIT', 'AST', 'BYTE', 'PYI', 'BRETT', 'SDAI', 'KUB', 'ROCK', 'WSBS', 'CPC', 'WELL', 'USDC(WormHole)', 'STBOT', 'EGG', 'HPO', 'BERRY', 'pogai', 'ARKN', 'TPU', 'DEVVE', 'X', 'MTS', 'BIZA', 'SNS', 'RFD', 'LFG', 'BLENDR', 'MOCHI', 'sUSDe', 'VIA', 'vAAVE', 'GOLC', 'CAU', 'xcDOT', 'PEPECOIN', 'VMPX', 'SIGN', 'CANTO', 'WCFX', 'LOVE', 'ZKML', 'CBP', 'STRDY', 'PRX', 'CHAPZ', 'ASTO', 'LENDS', 'CAF', 'WOLF', 'RANKER', 'MTC', 'CAW', 'RMV', 'WAM', 'GONE', 'NUUM', 'DOGGO', 'RED', 'CSAS', 'VEC', 'HEART', 'ZEPH', 'CLFI', 'AEGIS', 'PEAS', 'GUAC', 'EVMOS', 'PCI', 'GRAI', 'AMO', 'TYBG', 'SOLY', 'USTC', 'PIF', 'FORWARD', 'MK', 'AINN', 'AMAPT', 'CHONKY', 'NINJA', 'OBI', 'OGCINU', 'OSHI', 'VBETH', 'DOODOO', 'MIA', 'SMH', 'EMR', 'UPDOG', 'BRIUN', 'AI', 'NPC', 'IRON', 'GRAM', 'NFAI', 'RAB', 'ETHS', 'CWIF', 'BBC', 'FORK', 'AUDT', 'CAPO', 'MEME', 'EUL', 'DOGWIFHAT', 'TIP', 'F3', 'VSC', 'MXM', 'FLUXB', 'TYT', 'APP', 'SWITCH', 'ELG', 'MAR3', 'stATOM', 'DOLA', 'KCAL', 'DBZ', 'ANML', 'BABYWIF', '$STARLY', 'LMR', 'RJV', 'BYAT', 'USDC', 'BAI', 'FI', 'JUSDT', 'CHURRO', 'BTCA', 'CCC', 'RDEX', 'TIGRA', 'IRL', 'MNTA', 'DFNDR', 'ELGATO', 'TATSU', 'DAV', 'VPR', 'AIAT', 'WHY', '00', 'INS', 'SIX', 'LAKE', 'SHIB', 'PEPE', 'ULX', 'ETHX', 'vTRX', 'KNDX', 'SMILE', 'EETH', 'SUDO', 'WAS', 'ARC', 'SML', 'BIF', 'ZPAY', 'INTL', 'NAO', 'FAKEAI', 'BYTE', 'GEAR', 'PTH', 'VELA', 'GTA', 'MINU', 'NEX', 'FANC', 'SEOR', 'BEN', 'ferc', 'CAT', 'FUD', 'WSB', 'MCOIN', 'NOVA', 'LUCKYSLP', 'POLYDOGE', 'MCONTENT', 'VARA', 'MBD', 'CVXFXS', 'LIF3', 'KNINE', 'DERP', 'GAMBIT', '0KN', 'WFT', 'MARVIN', 'NITO', 'MELD', 'AGB', 'NGL', 'lisUSD', 'OCT', 'ANUS', 'USDZ', 'CRE', 'ROSX', 'STORE', 'GAYPEPE', 'AIX', 'PICA', 'WCKB', 'SMART', 'FACT', 'SEXY', 'MPIX', 'HBB', 'USK', 'BCA', 'LNDX', 'ROG', 'ALPHA', 'PEPE', 'DZOO', 'TRESTLE', 'FXC', 'DIGI', 'BIBI', 'TOPIA', 'SMURF', 'DTORO', 'MIM', 'DKS', 'ISHI', 'GAMI', 'BORING', 'SBR', 'CSWAP', 'MTC', 'ZZZ', 'CLY', 'OMI', 'AGEUR', 'MYRA', 'GEKKO', 'JEN', 'TBANK', 'SGB', '$ADS', 'MZERO', 'EMC', 'wxDai', 'STAMP', 'DEXNET', 'AIEPK', 'SOMM', 'HBD', 'APED', 'KERMIT', 'ROND', 'SPACEPI', 'BTRFLY', 'WOOF', 'CWT', 'QTO', 'GINUX', 'NETT', 'BNBX', 'CAJ', 'CULO', 'SQT', 'ARX', 'ZEDXION', 'LINU', 'PEPINU', 'WMINIMA', 'shibai', 'WELSH', 'CDOGE', 'BABYTROLL', 'VOW', 'KIRA', 'SRT', 'LOCK', 'BUILD', 'NFE', 'TLC', 'FIT', 'CAMLY', 'RAFF', 'GAU', 'BOBO', 'DSYNC', 'PUMP', '4CHAN', 'TONNEL', 'SCNSOL', 'GHO', 'LYNX', 'AI', 'PANDO', 'KARATE', 'OCTA', 'SUI', 'SOON', 'WBX', 'IAG', 'PIGEON', 'TYPE', 'LIXX', 'FTI', 'OX', 'DORKL', 'XRGB', 'AIMX', 'FROGE', 'FEG', 'RSC', 'PIX', 'MGG', 'ABEY', 'EGX', 'GLFT', 'BCOIN', 'RODAI', 'WTK', 'SHIB2.0', 'NLC', 'X2Y2', 'COMAI', 'TANPIN', 'CHMPZ', 'MMVG', 'CRETA', 'BMAX', 'LEOX', 'GROKCEO', 'GYMNET', 'ankrBNB', 'SOLAR', 'SBF', 'MUSK', 'ACRIA', 'SOUL', 'BAZED', 'ROKO', 'OZONE', 'REACH', 'BISO', 'ZKP', 'MND', 'CHINU', 'FP', 'PIZA', 'MATICX', 'IRT', 'TGC', 'MOROS', 'GRAPE', 'BEN', 'ZYPTO TOKEN', 'ABR', 'RBT', 'DONGO', 'FOTTIE', 'AI', 'AC', 'FAKT', 'BLACKDRAGON', 'ASTRA', 'UNLEASH', 'AXT', 'ZKHIVE', 'KBD', 'REF', 'ANON', 'OMNOM', 'WMOVR', 'XVG', 'DINO', 'INAE', 'VIRTUAL', 'KABOSU', 'OZONE', 'AVI', 'QI', 'XRUN', 'SPACEPI', 'ARKER', 'PAI', 'MMM', 'BOZO', 'AICODE', 'ERN', 'VSUI', 'FACTR', 'FXD', 'ROCKY', 'KEP', 'CKP', 'VITA', 'MUMU', 'HAHA', 'PALAI', 'MIND', 'PBX', 'AIN', 'MSQ', 'SUIP', 'ECLD', 'ARS', 'FAME', 'GGG', 'NESS', 'SWIFTIES', 'MDT', 'FACEDAO', 'TADA', 'ETHG', 'BASE', 'USX', 'RAIN', 'FSC', 'FDT', 'XD', 'REAL', 'CX', 'TALK', 'PNDC', 'FTRB', 'KREST', 'KINGY', 'SRX', 'DIS', 'ZED', 'MAI', 'OBT', 'TOKA', 'CAL', 'ELS', 'PET', 'ISSP', 'MC', 'HON', 'MC', 'KICKS', 'WJEWEL', 'BEFE', 'HEFI', 'ICE', 'MIM', 'MYTH', 'FLAME', 'OX', 'BRZ', 'CANDY', 'HXD', 'KORRA', 'TURBOS', 'TAPROOT', 'BLD', 'PI', 'HALO', 'CGV', 'SOLZILLA', 'COW', 'BRCT', 'MEME', 'LOAF', 'GMTO', 'DOGI', 'CLNX', 'WASSIE', 'PRINT', 'FUD', 'LAVA', 'ACT', 'RWN', 'SEILOR', 'TOTO', 'GBEX', 'PG', 'EVO', 'PEPEBRC', 'NALS', 'RCM', 'ETH2X-FLI', 'WKAS', 'TAKI', 'NEAT', 'NS', 'BEPE', 'FUTURE', 'DOG', 'EJS', 'XPE', 'GPUINU', 'AURA', 'PAYS', 'FOOD', 'osETH', 'CRAZYBUNNY', 'IUSD', 'MELOS', 'XX', 'PSUB', 'SOLO', 'APE', 'ICNX', 'SQUID', 'WCORE', 'CATE', 'PAW', 'VES', 'KAP', 'ELUSKMON', 'BOMB', 'TXP', 'HSUITE', 'KIRBY', 'CIRCLE', 'CAD', 'LEE', 'CLOUD', 'GECKO', 'MVX', 'LICK', 'VCORE', 'HPY', 'SCS', 'RBNB', 'OSAK', 'CROWN', 'OMN', 'VRX', 'YAK', 'REDLUNA', 'EQ', 'RING', 'PHAUNTEM', 'HYPC', 'VSG', 'WIOTX', 'PORT', 'FRGX', 'JAN', 'LOONG', 'XRPAYNET', 'MEOW', 'WTFUEL', 'ALT', 'VRL', 'FINE', 'INDEX', 'UBU', 'ORAIX', 'MILLI', 'MVP', 'GCAKE', 'SILLYCAT', 'GNX', 'MMX', 'WINR', 'RSTK', 'GROW', 'YOM', 'RYOSHI', 'FNCT', 'OBOT', 'BOB', 'HO', 'FINE', 'MUNITY', 'MMF', 'SMOL', 'DOGE2.0', 'SAFE', '$BULL', 'WAGIEBOT', 'TAP', 'PLN', 'IXT', 'HAKA', 'MOE', 'WX', 'HUAHUA', 'FUNCH', 'HMT', 'CREDI', 'GLINT', 'KNFT', 'XERS', 'USP', 'USDY', 'SIMP', 'DOGS', 'AGII', 'AA', 'NSDX', 'LOOP', 'HIPP', 'COL', 'LUMI', 'SDCRV', 'SYL', 'DOMI', 'MBLK', 'RABBIT', 'SOLNIC', 'NLS', 'CTP', 'FMC', 'PIF', 'D3D', 'ENG', 'PROTEO', 'DFT', 'FOUR', 'BABYTRUMP', 'PRB', 'HYCO', 'ECLIP', 'WIGO', 'CVXCRV', '$L', 'SON', 'EQX', 'SOAI', 'SEAM', 'MURATIAI', 'EPIKO', 'TRU', 'VUZZ', 'YDF', 'BIT', 'SOLANA', 'RBC', 'ZKPEPE', '369', 'WCFG', 'ACT', 'SPT', 'METANO', 'SCB', 'BLACK', 'ECOIN', 'KIZUNA', 'DIVER', 'VONSPEED', 'FLOKICEO', 'FOLD', 'SWEEP', 'RAKE', 'BRATT', 'APFC', 'OWL', '$OPHX', 'ORBIT', 'BAOS', 'SMRT', 'JOE', 'JNB', 'UGOLD', 'JFIN', 'STON', 'MRHB', 'GROK 1.5', 'HST', 'SPURDO', 'SOC', 'WIT', 'SOPH', 'MUTE', 'P3D', 'EQ', 'VPAD', 'SHIBAAI', 'BLAST', 'stTIA', 'ALV', 'ATPAY', 'BUFFET', 'CHUB', 'KOIN', 'FLX', 'SSHIB', 'ECOTERRA', 'MEER', 'REAL', 'EMP', 'ARBI', 'CGL', 'ARBUZ', 'NHCT', 'XFI', 'SPOL', 'AMKT', 'DUBBZ', 'RIDE', 'BULL', 'GULF', 'GWD', 'ZKID', 'NEMS', 'PLB', 'BCB', 'GSX', '$PEEP', 'VAULT', 'BABYPEPE', 'REALM', 'LYXe', 'BYTES', 'DEFY', 'DCARD', 'LCRO', 'JUNO', '$GENE', 'LQ', 'WSTOR', 'KLKS', 'NEUROS', 'KT', 'THOR', 'OXN', 'ADDAMS', 'FON', 'SMCW', 'MGP', 'RENQ', 'KCAKE', 'SFL', 'xXx', 'SONNE', 'RISITA', 'PRIMAL', 'NINU', 'JKL', 'GHUB', 'THOREUM', 'DMT', 'RABI', 'WASTR', 'HMTT', 'MMPRO', 'PEPI', 'BIOFI', 'AQUA', 'FAST', 'FXI', 'INU', 'TND', 'PLSARB', 'MKT', 'NEW', 'SEKAI', 'VERA', 'stMATIC', 'LVL', 'GRELF', 'DMCC', 'EQU', 'SPRT', 'SHIBDOGE', 'PLXY', 'CAPP', 'MYRIA', 'MTS', 'WWDOGE', 'RFKJ', 'SSE', 'FJT', 'MGC', 'JTC', 'GALAXY', 'STONKS', 'NFD', 'EDUM', 'IXS', 'AZURE', 'AQTIS', '$SNOOPY', 'CHMB', 'CHATGPT', 'WEAR', 'BLOCK', 'KNJ', 'PAYN', 'ANDY', 'VRD', 'SFRXETH', 'CHANGE', '$SPONGE', 'XAH', 'TPAD', 'FRR', 'MEAN', 'GGAVAX', 'BURRRD', 'MB4', 'LDZ', 'DGLN', 'HUT', 'OETH', 'ARCHIVE', 'FPIS', 'SRLTY', 'TRUMP INU', 'GOHM', 'MDI', 'SEAT', 'BTCT', 'HIT', 'SAP', 'ONI', 'BFG', 'REBUS', 'LET', 'DOGECEO', 'HOSTAI', 'EShib', 'MONIE', 'LYUM', 'AITK', 'SAVG', 'EOSC', 'PDX', 'ASTRO', 'FORE', 'RST', 'TRSCT', 'DEBT', 'SBONK', 'PEEPO', 'BCAT', 'LENFI', 'FNZ', 'SOLAV', 'CBSL', 'xDAI', 'CRYSTAL', 'INST', 'KUSUNOKI', 'CLH', 'POTATO', 'DG', 'DINO', 'PALM', 'AMC', 'KAIJU', 'GM', 'FINC', 'SNST', 'GIAC', 'MORRA', 'LGX', 'METO', 'DYP', 'TRUMP', 'SG', 'KVERSE', 'SCAR', '1SOL', 'SPC', 'IC', 'BEAR', 'DUG', 'REVU', 'CRAZY', 'CCASH', 'ZAM', 'BABYTRUMP', 'KEKEC', 'PRXY', 'BSGG', 'CAT', 'MILOCEO', 'BABYCEO', 'AKTIO', 'DAWG', 'MAI', 'RBT', 'AIA', 'GM', 'THB', 'BABYPEPE', 'HDX', 'ACM', 'MM', '$HUB', 'SPECTRE', 'BURNS', 'TEM', 'WEVER', 'BTCIX', 'DWARS', 'PIIN', 'JET', 'SQUAD', 'PLT', 'MOBX', 'HAO', 'NOOT', 'FREL', 'BOARD', 'HOTKEY', 'NOTHING', 'WCDONALDS', 'EVDC', 'BNBDOG', 'CRYN', 'DLLR', 'GGTK', 'XRPC', 'LUNR', 'VICS', 'TKST', 'HSUI', 'WEBAI', 'SEAN', 'THING', 'BABYMUSK', 'CATFISH', 'KING', 'DOGE-1', 'JOLT', 'STNEAR', 'YAY', 'VT', 'AIUS', 'AIAKITA', 'DVRS', 'CREDIT', 'FRONK', 'TMC', 'WUSD', 'IBIT', 'VICA', 'CUMINU', 'CAL', 'LQDX', 'LUNCARMY', 'MLXC', 'QKNTL', 'SRBP', 'GGP', 'MCN', 'ATECH', 'CARAT', 'BHAT', 'ZETRIX', 'ALOT', 'PORTAL', 'BIO', 'KURO', 'SPOT', 'ASM', 'kitty', 'LYF', 'WOJAK2.69', 'GEOD', 'INSC', 'LOST', 'LGBT', 'SCRL', 'XFLOKI', 'HUSKY', 'DUA', 'GOLDEN', 'TBC', 'DSFR', 'VEIL', 'CEO', 'CS', 'XOX', 'EURe', 'OGY', 'eUSD', 'ARCAS', 'CPU', 'KINT', 'MWCC', 'BABYDRAGON', 'ATRNO', 'CYBA', 'SMT', 'GAMMA', 'GOLD', 'NEONAI', 'TRUMP2024', 'SPELLFIRE', 'CR', 'SPARTA', 'BABYSORA', 'BAG', 'METAL', 'stDYDX', 'ZZ', 'RVST', 'ECOREAL', 'LUFFY', 'ZINU', 'UNMD', 'OPTIMUS AI', 'KTT', 'WGT', 'FUSDC', 'PSL', 'BLOCK', 'PAYU', 'WEB', 'GMR', 'AFD', 'WEC', 'MOETA', 'BOX', 'PIG', 'BMEX', 'WPOKT', 'BURN', 'STIMA', 'CCHG', 'FXB', 'SAT', 'MESA', 'TROVE', 'ZENIQ', 'SCANS', 'ASM', 'PAC', 'DFND', 'BIDEN', 'THE', 'NEOX', 'EVU', 'SHD', 'SEND', 'A4M', 'TRIBL', 'LKT', 'PWC', 'TFI', 'WATT', 'CENX', 'MINAR', 'MMT', 'SUIA', 'MEX', 'XPB', 'TRACE', 'CIF', 'SGT', 'TIPS', 'BEAR', 'FIST', 'ANG', 'CNG', 'CATS', 'TRI', 'ASTRO', 'RVM', 'DEXTF', 'XFT', 'MATA', 'PIRI', 'RING', 'AUR', 'NEXM', 'SFM', 'HODL', 'FT', 'MAGA', 'STEAK', 'SHEZMU', 'SKB', 'GWGW', 'CTEX', 'LNR', 'REKT', 'FID', 'MMT', 'MAI', 'AIPEPE', 'PASG', 'HERMES', 'UNIDEXAI', 'AIR', 'SOBER', 'NEKO', 'SUNNY', 'IDO', 'PLS', 'Bear', 'PLUG', 'FLIGHT', 'BOXETH', 'CRAMER', 'SABAI', 'ASH', 'RBC', 'HMX', 'OCC', 'AI', 'ECTE', 'GVC', 'WELD', 'CRVFRAX', 'SAMA', 'NOVA', 'DYNMT', 'CAI', 'BRGE', 'AIMBOT', 'PLX', 'YAK', 'PLQ', 'GOMT', 'DPX', 'DVP', 'LEMN', 'MNTL', 'PSI', 'ORACLE', 'FMC', 'YCT', 'GALEON', 'MTRM', 'KOGE', 'LYNK', 'PUMP', 'wROSE', 'STZETA', 'FLOKIBURN', 'WZETA', 'MANIA', 'CHAT', 'ENO', 'EMOJI', 'XTREME', 'SWISE', 'SPONGE', 'OLAND', 'CREPE', 'VRSW', 'ANTC', 'LIZA', 'HOP', 'UBSN', 'OMMI', 'WHT', 'LAVITA', 'CADINU', 'TARAL', 'KRRX', 'BOK', 'MAPE', 'FROG', 'FOOM', 'PKT', 'OTSEA', 'FPS', 'EDAT', 'MZR', 'DCHF', 'RAIL', 'OASIS', 'BLXM', 'IONX', '$KABOSU', 'STSW', 'ASEED', 'FLOYX', 'SPIZ', 'CYCON', 'SIPHER', 'EARN', 'WDOGE', 'NWS', 'GTN', 'DIS', 'LEO', 'NEWM', 'SOLAR', 'CVIP', 'UT', 'JONES', 'B2M', 'ZIX', 'AIKEK', 'vTUSD', 'SMART', 'SAITABIT', 'MEGALAND', 'DRAGON', 'SCALE', 'ESG', 'PUPPIES', 'TRUMP', 'GFT', 'MTHN', 'PRNT', 'ARCH', 'EGC', 'LUXY', 'PAXU', 'EQ9', 'DEGA', 'SHIBA', 'GUILD', 'MAGA', 'BSL', 'cats', 'ZOA', 'LPOOL', 'TUCKER', 'JNX', 'BEBE', 'GROK', 'HTT', 'EXTRA', 'IPX', 'STEMX', 'LOOT', 'MNR', 'AVTM', 'BENJI', 'RBX', 'MOONEY', 'EVEAI', 'PC', 'ANGLE', 'TGPT', 'VOLT', 'BLACK', 'ITHEUM', 'TGT', 'LBTC', 'UCX', 'LFG', 'WEAPON', 'AXO', 'PLEX', 'SOBB', '$LAPTOP', 'SLC', 'LIMO', 'BSWAP', 'NFTS', 'CALI', 'BTC2.0', 'XLS', 'LBT', 'EGRN', 'ZOOMER', 'RNDX', 'ITX', 'SVN', 'BTCINU', 'PSB', 'WRT', 'X', 'LMAO', 'RAVEN', 'BIIS', 'CHEERS', 'MEOW', 'SBABE', 'EVA', 'DOGECOIN', 'MNFT', 'YOTO', 'ATNT', 'REUNI', 'NAOS', 'MICKEY', 'HADES', 'EUROE', 'LOFI', 'UGAS', 'HOLDEX', 'MARVIN', 'WJXN', 'NZERO', 'MAGA', 'FAVR', 'EMAID', 'MANDOX', 'BBT', 'DDD', 'TORI', 'BOX', 'WKC', 'PINU', 'DHLT', 'BESA', 'GCC', '$HMT', 'SEX', 'QMALL', 'SFTMX', 'ITA', 'GNOME', 'OORC', 'HERA', 'MTR', 'VXT', 'SONAR', 'stAPT', 'UXP', 'HE', 'BTCMT', 'DOGPAD', 'USDs', 'LARIX', 'ODGN', 'ASTRADAO', 'NEWG', 'PLCU', 'GFLY', 'VNO', 'GRUM', 'LIZARD', 'XENO', 'WHALE', 'UNSHETH', 'INU', 'KIBA', 'BXC', 'DOLZ', '$PEPE', 'SOLSPONGE', 'FXY', 'AET', 'GBOY', 'GROK', 'NVX', 'EGC', 'SILV2', 'RBP', 'GOKU', 'SIZ', 'BVC', 'IPMB', 'FIWA', 'REDDIT', 'JUMBO', 'PRI', 'HODL', 'UNP', 'HAY', 'KDOE', 'D2T', 'EQB', 'TRIVIA', 'KNS', 'KON', 'FREN', 'TRI', 'LILA', 'DLY', 'PEPE', 'ATH', 'FANX', 'WXDC', 'CMCX', 'XLT', 'METAV', 'BOOK', 'MCT', 'IUX', 'HBT', '$INR', 'MGT', 'SPOOL', 'EQUAL', 'STARS', 'DUSD', 'XPLL', 'UNQ', 'KFI', 'STL', 'MEMES', 'BEMD', 'DEFIDO', 'XODEX', 'EPIX', 'PNL', 'IVY', 'XDAO', 'LION', 'TXT', 'MFAM', 'VENT', 'GTX', 'IBTC', 'HYPES', 'XAI', 'MARU', 'NT', 'PUFF', 'GP', 'SILK', 'PPI', 'MTC', 'PTX', 'CNC', 'JARY', 'FAV', 'DV', 'MAYP', 'CRF', 'Cheems', 'NIOX', 'GGT', 'TRUMP', 'FALCONS', 'CORGI', 'NMD', 'MOBI', 'ECOX', 'GRL', 'DD', 'LIT', 'THT', 'NGC', 'SAUCEINU', 'EVE', 'CAVADA', 'SOLR', 'ULTRA', 'HONK', 'EXCC', 'BLAST', 'KAI', 'GMEX', 'TTM', 'ATEM', 'OSHI', 'UCON', 'M87', 'SIMPSON', 'EGS', 'SASHIMI', 'GAIA', 'bPRIVA', 'STRIP', 'MAJO', 'OSQTH', 'KNK', 'OCN', 'CNG', 'CC', 'MPH', 'OCD', 'mCUSD', 'EXEN', 'BFHT', 'MEGA', 'DEB', 'INSP', 'BUDDHA', 'ICG', 'PIN', 'SFIN', 'TSC', 'SHIT', 'EXD', 'AKITAX', 'JPEG', 'BOSS', 'PONKE BNB', 'GTC', 'ZCN', 'EVR', 'MELANIA', 'LMCSWAP', 'CLASS', 'NPICK', 'MIMATIC', 'INK', 'PAPA', 'LORDS', 'BEETS', 'JBX', 'RYOMA', 'BTTY', 'TIDE', 'CFXQ', '4JNET', 'AIE', 'GHNY', 'BPET', 'CELT', 'KUNAI', 'RFT', 'GRAPE', 'ZAT', 'PIXEL', 'RDT', 'ABC', 'ALD', 'WNK', 'HOLD', 'MODEX', 'FERMA', 'EGAME', 'NCO', 'MODA', 'W3S', 'SDOGE', 'ATOZ', 'WONE', 'THOL', 'FTHM', 'GIB', 'CLUB', 'ONUS', 'YFX', '3KM', 'WCA', 'DMS', '2DAI', 'GEMINI', 'DEOD', 'GBPT', 'BSPT', 'BSX', 'ERTH', 'CROID', 'GROW', 'AIX', 'ZPT', 'ELK', 'MAG', 'JAY', 'Ari10', 'SAUDIBONK', '$BSV', 'BANK', 'ATEM', 'XPAY', 'QR', 'SRM', 'DMOON', 'KAF', '$TMNT', 'MYTH', 'GOLD', 'JUP', 'LUNCH', 'ADA', 'AIRB', 'FORA', 'FRC', 'USHARK', 'CIX', 'KOMPETE', 'ASS', 'CPC', 'YACHT', 'CLIPS', 'PGX', 'MEMEME', 'ADOGE', 'SCM', 'POP', 'BGN', 'PTP', 'HSC', 'DRAC', 'UWU', 'THALES', 'IST', 'MAIA', 'BABYSHIB', 'PHCR', 'COLT', 'MMC', 'BTO', 'BNX', 'DBD', 'RAM', 'KAKI', 'WGRT', 'GENS', 'XSP', 'TROSS', 'SAFEMARS', 'TITA', 'CAT', 'QIE', 'TCT', 'TTT', 'ATK', 'FREN', 'REL', 'SOLEX', 'UVT', 'IRENA', 'ONS', 'ZODI', 'PI', 'BABI', 'TNC', 'STC', 'STRIP', 'DOGE-1', 'AXL', 'stOSMO', 'LAIKA', 'XPX', 'PHM', 'LBA', 'MBASE', 'XI', 'VIDYX', 'CODEX', 'BIG', 'WECO', '3P', 'NMT', 'SOLID', 'BRRR', 'ARTR', 'HILO', 'SPAY', 'CHICA', 'DFX', 'ONC', 'GEMSTON', 'ZUCKPEPE', 'PARAS', 'MDX', 'IDYP', 'FFM', 'PAI', 'RIA', 'WHIRL', 'CHAMP', 'SORADOGE', 'GIP', 'DFI', 'TRI', 'NAS', 'SOLANA', 'JPYC', 'ASTRA', 'CRAYRABBIT', 'AWM', 'ALPA', 'NII', 'ZLK', 'IGUP', 'POX', 'TOOLS', 'VEST', 'SOH', 'XNFT', 'IMT', 'STAR', 'KIF', 'CRE', 'SILO', 'DIS', 'GDCC', 'SUPE', 'XFUND', 'FUZN', 'UNIDX', 'CAI', 'CIR', 'FOMO', 'FIRE', 'DOP', 'XSAUCE', 'AGRO', 'FAN', 'PEN', 'LIEN', 'SFTY', 'RENT', 'EMPIRE', 'MM', 'VST', 'GFT', 'CIND', 'SNAP', 'MINI', 'MDA', 'RIA', 'CHAIN', 'BOBO', 'GEM', 'GAYSLER', 'VOLR', 'DPY', 'CART', 'XRAI', 'DUCK', 'RKR', 'NBOT', 'HIT', 'AJNA', 'VADER', 'DINGER', 'BABYLONG', 'LSD', 'BOMB', 'CTN', 'HID', 'KLUB', 'SYNR', 'TSHARE', 'KABOSU', 'ADEL', '$YAKU', 'AFG', 'BIBL', 'DHP', 'RDN', 'SHIELD', 'GSYS', 'MCRN', 'BLUES', 'DARC', 'DEUS', 'CYS', 'VIDY', 'VP', 'WISE', 'UNDEAD', 'BRD', 'MDF', 'BAKED', 'ASCN', 'CS', 'WAR', 'HDV', 'LODE', 'OST', 'LOON', 'GXE', 'OPV', 'SDOGE', 'BAJU', 'GLI', 'COFI', 'LYRA', 'DOC', 'NPM', 'GEMINI', 'RED', 'NBP', 'XAI', 'MNZ', 'MVG', 'DSRUN', 'GGM', 'HABIBI', 'IHT', 'MARS', 'COFI', 'BIOP', 'BTL', 'PORTX', 'LEMO', 'DXCT', 'PRT', 'MRCH', 'REM', 'RBD', 'LZM', 'ROUP', 'CBANK', 'CSTR', 'DUCK', 'TFS', 'KPAD', 'SOP', 'BXBT', 'IZE', 'BAGS', 'BNTY', 'LEMD', 'KRIDA', 'MTN', 'FST', 'FNF', 'BABYDOGE2.0', 'STI', 'NITRO', 'EOSDAC', 'ATP', 'GINOA', 'MIMIR', 'GIDDY', 'WTHETA', 'DFY', 'RIK', 'vLUNA', 'BIFI', 'ESS', 'LFG', 'XPRESS', 'PKN', 'NUT', 'CORAL', 'PINE', 'UNN', 'JUSTICE', 'DUCX', 'MDS', 'BOLT', 'WKLAY', 'BDT', 'NLINK', 'VCX', 'HCT', 'MLNK', 'JFIVE', 'KUMA', 'LINQ', 'BXH', 'BALD', 'OPN', 'LIQ', 'RAM', 'TI', 'GDT', 'MOVE', 'GUARD', 'LBLOCK', 'VTX', 'TMNG', 'INVI', 'FDC', 'FWW', 'GAI', 'MF', 'MC', 'EVERMOON', 'SLNV2', 'BDCL BSC', 'ASIA', 'SHARBI', 'XMC', 'ETERNAL', 'MINER', 'ASG', 'CHILI', 'CCV2', 'GOD', 'CHAMPZ', 'BCDN', 'PST', 'USA', 'TREAT', 'MCL', 'NINKY', 'SX', 'AMAZINGTEAM', 'NXN', 'QBT', 'SNTR', 'VERI', 'INS', 'BANANA', 'PSY', 'ASY', '0XGAS', 'ZPC', 'EVERMOON', 'GAS', 'TETHYS', 'LIS', 'RCN', 'XMX', 'SOURCE', 'GPT', 'OVN', 'VARK', 'SER', 'FRGST', 'MINE', 'ENCS', 'PAF', 'PHTR', 'T23', 'ARBS', 'DHX', 'GSE', 'SBTC', 'GIGA', 'EHASH', 'MLS', 'ZTG', 'BFT', 'LIQD', 'USDTV', 'ASTROC', 'SPYRO', 'NEURONI', 'WDOT', 'TRUMP', 'MSHD', 'USDGLO', 'CARR', 'APW', 'F1C', 'JCO', 'AKT', 'MCO2', 'MGPT', 'TITAN', 'MNB', 'Teddy V2', 'WAG', 'BUMP', 'ELEC', 'FLAME', 'BFR', 'PTS', 'NINJA', 'MHUNT', 'PIZA', 'SEC', 'GEC', 'ONX', 'SYNTH', 'XACT', 'EPAN', 'YIN', 'PEAR', 'SECT', 'TRCL', 'ZURR', 'CBY', 'FUEL', 'MIC', 'KBOX', 'SINGLE', 'ATS', 'BRUSH', 'STX', 'MXT', 'EG', 'CHD', 'OCAI', 'HACHI', 'MEPAD', 'HERA', 'OVO', 'CRT', 'JEFF', 'wSIENNA', 'DXN', 'WADA', 'QASH', 'SOL', 'FILDA', '$FM', 'WANNA', 'RAK', 'PPAD', 'CTR', 'COC', 'PORA', 'FOREX', 'POPK', 'FARMS', 'RICE', 'JEFF', 'RATIO', 'AES', 'AVO', 'WOOO', 'SKM', 'DEK', 'AAA', 'HTE', 'VMT', 'MMY', 'DANA', 'NAV', 'UNQ', 'UCJL', 'VRO', '4TOKEN', 'PERA', 'BOMB', 'CAT', 'FREE', 'OS', 'WFO', 'XDAG', 'UUSD', 'TON', 'NVG', 'TAI', 'WPEPE', 'AITEK', 'ARTEM', 'ICONS', 'HOME', 'XSB', 'XCEPT', 'YESP', 'KAKA', 'HGHG', 'tAPT', 'CHAT', 'POT', 'VEE', 'MET', 'CRDC', 'PSWAP', 'GDC', 'PRIDE', 'OME', 'ETP', 'REAL', 'BCNT', 'JFI', 'YYAVAX', 'QTC', 'SPXC', 'INDI', 'POU', 'ORO', 'FAME', 'CLOUD', 'CHER', 'ALF', 'EPETS', 'SKT', 'RATING', 'CONE', 'DES', 'DACAT', 'BP', 'PLT', 'METAN', 'BS', 'CASINU', 'MIS', 'OPA', 'WZM', 'F2C', 'SRG', 'NANA', 'KFC', 'MQL', 'CORN', 'MOOO', 'FLURRY', 'TPAD', 'JNGL', 'WNEON', 'MOT', 'WEX', 'CUP', 'BACON', 'ARCADE', 'WNZ', 'BAMBOO', 'KGC', 'WTG', 'OPMND', 'KNOT', 'RIBBIT', 'SNK', 'DMLG', 'SPHRI', 'THEOS', 'IMAYC', 'EMON', 'MGA', 'MATCH', 'REIGN', 'BLIN', 'PANDA', 'ENNO', 'SPEX', 'B3X', 'TBTC', 'GOV', 'TOMB', 'SKRT', 'D2O', 'ZSC', 'MCASH', 'SOLPAD', 'ISKY', 'SATOSHI', 'MART', 'MOJO', 'GODE', 'NOA', 'VALUE', 'TSHP', 'TTK', 'UW3S', 'Teller', 'STZ', 'UNDEAD', 'TARI', 'SRP', 'BLOB', 'TAUR', 'ZONE', 'PSPS', 'PROB', 'DILI', 'ETI', 'SMF', 'MELI', 'SAIL', 'CV', 'MOTG', 'OCICAT', 'DELI', 'RIM', 'BAS', 'AAG', 'SMR', 'MTG', 'FODL', 'ALM', 'BOX', 'XET', 'OPS', 'BURP', 'AUTUMN', 'PGT', 'QLINDO', 'SONIC', 'CANCER', 'XETH', 'TSL', 'HOPPY', 'BOOT', 'NUT', '$RDF', 'FILST', 'UMMA', 'DOS', 'EFT', 'TTC', 'PRE', 'SNFTS', 'MANE', 'LEV', 'FOXY', 'KTK', 'STKBNB', 'CAPY', 'ENV', 'MT', 'OPEN', 'FWB', 'SHEB', 'DCRN', 'ITEM', 'CNAME', 'SCY', '$BONG', 'WISTA', 'NFTL', 'MoFi', 'NFTBS', 'LSD', 'MGKL', 'HOLD', 'stEVMOS', 'JUGNI', 'stINJ', 'G1X', 'LOA', 'USDR', 'DEGEN', 'OGSM', 'VD', 'TBE', 'XNP', 'MEGAHERO', 'USH', 'CHOKE', 'TREMP', 'GBD', 'LEIA', 'SPIN', 'RIN', 'DOGEGF', 'MYST', 'CSC', 'ARRO', 'EMP', 'DAL', 'SWU', 'MOI', 'CEM', 'GETA', 'NOLA', 'ARB', 'BVT', 'MOONED', 'APU', 'CHFT', 'pBTC35A', 'AIS', 'EFK', 'HDRN', 'CRAFT', 'FKPEPE', 'ONNO', 'DFD', 'DFL', 'HBARX', 'PLCUC', 'GTCOIN', 'HAT', 'KWAI', 'LFNTY', 'PARA', 'CTR', 'KAU', 'CUT', 'EDUX', 'BLES', 'GNOME', 'QTF', 'NEPT', 'MNST', 'LTX', 'PLACE', 'AMT', 'OLEA', 'PHAME', 'BUGS', 'BTAF', 'CHAD', 'JIM', 'XPTP', 'ATD', 'CNNS', 'MAX', 'SAL', 'BCX', 'LOPES', 'SNET', 'BKN', 'PLS', 'MBOT', '$GF', 'MAGICK', 'GRBE', 'COINSCOPE', 'FIDO', 'GAMES', 'DELFI', 'HOA', 'TRG', 'NXD', 'BTAMA', 'SDR', 'NKCLC', 'HMNG', 'VOLTA', 'WUSDR', 'PUGAI', 'PACT', 'GM', 'SWAY', 'WOOOOO!', 'CYBER', 'ASH', 'SYM', 'SATOX', 'BTCPX', 'KAG', 'BTCV', 'DEC', 'FKSK', 'MJT', 'SONA', 'POLYPAD', 'SWOT', 'WELA', 'JP', 'BERN', 'NOVA', 'OKINAMI', 'RB', 'WARPED', 'LINKFI', 'CLAY', 'ORD', 'RENEC', 'CWT', '0XL', 'BITO', 'WOOL', 'LWC', 'CSOV', 'LQDR', 'MOE', 'ND', 'WINTER', 'NMX', 'ESW', 'RIB', 'GORA', 'MVI', 'OPAIG', 'GENS', 'ROBIN', 'GOFX', 'ANI', 'VTG', 'QSR', 'AUD', 'DAO', 'DOGECUBE', 'SFEX', 'CAIR', 'XIL', 'SMILEK', 'DEVT', 'XDOGE', 'QWT', 'SIFU', 'MTRK', 'SWAP', 'FBX', 'NIIFI', 'JEUR', 'mCEUR', 'SMUDGE', 'SFL', 'PALM', 'RAFT', 'VMS', 'DOGS', 'MFET', 'BEFTM', 'VC', 'PD', 'HON', 'ALTB', 'RVLNG', 'SETH2', 'XOT', 'PEARL', 'APING', '$FORGE', 'AGN', 'HLN', 'XCFX', 'GAN', 'BPLC', 'MCT', 'SU', 'FCTR', 'CZZ', 'VATRENI', 'RAKE', 'BlueSparrow', 'DGNX', 'MZM', 'ITSB', 'SNMT', 'PAVIA', 'EFFORT', 'IPOR', 'LOVE', 'TOSHE']

# %%
dummy_data = pd.DataFrame(cypto_symbol, columns=['symbol'])

# %%
dummy_data.to_csv("crypt_symbol.csv")

# %%
import requests

def get_crypto_price(symbol):
    url = f'https://pro-api.coinmarketcap.com/v1/cryptocurrency/quotes/latest'
    parameters = {
        'symbol': symbol.upper(),
        'convert': 'USD'  # You can change this to convert to other currencies
    }
    headers = {
        'Accepts': 'application/json',
        'X-CMC_PRO_API_KEY': 'a9369a4d-1231-4827-a774-93a18e73caec',  # Replace with your API key
    }

    try:
        response = requests.get(url, params=parameters, headers=headers)
        data = response.json()
        if 'data' in data and symbol.upper() in data['data']:
            price = data['data'][symbol.upper()]['quote']['USD']['price']
            return price
        else:
            return None
    except Exception as e:
        print("Error:", e)
        return None

# Example usage:
crypto_symbol = 'BTC'  # Replace with the symbol of the cryptocurrency you want to get the price for
price = get_crypto_price(crypto_symbol)
if price is not None:
    print(f"The current price of {crypto_symbol} is ${price}")
else:
    print(f"Failed to retrieve the price of {crypto_symbol}.")
# Out:
# The current price of BTC is $66867.47953293826

# %%
import requests

def get_historical_data(symbol, start_date, end_date, convert='USD'):
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/historical'
    parameters = {
        'symbol': symbol.upper(),
        'time_start': start_date,
        'time_end': end_date,
        'convert': convert
    }
    headers = {
        'Accepts': 'application/json',
        'X-CMC_PRO_API_KEY': 'a9369a4d-1231-4827-a774-93a18e73caec',  # Replace with your API key
    }
    try:
        response = requests.get(url, params=parameters, headers=headers)
        data = response.json()
        print(data) 
    except Exception as e:
        print("Error:", e)


get_historical_data('BTC', '2021-01-01T00:00:00Z', '2021-01-02T00:00:00Z', 'USD')
# Out:
# {'status': {'timestamp': '2024-03-18T15:17:54.360Z', 'error_code': 1006, 'error_message': "Your API Key subscription plan doesn't support this endpoint.", 'elapsed': 0, 'credit_count': 0}}

# %%
from Historic_Crypto import HistoricalData

new = HistoricalData('ETH-USD',300,'2020-06-01-00-00')
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Checking input parameters are in the correct format.
